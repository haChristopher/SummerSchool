# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5244, 3082, 12, 6, 195, 2, 3136, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'originated', 'term', 'as', 'term', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.813805
# Nearest to they: navigators, ozzfest, bookmakers, africanus, dmt, practicing, vilna, altenberg,
# Nearest to all: contributions, ethnicity, trained, stacking, recognize, provisioning, fifteenth, quaid,
# Nearest to five: hellespont, braille, bursa, pharaoh, moraines, gerson, under, toxic,
# Nearest to three: faroes, am, virginals, transatlantic, ims, madrigal, spends, algebra,
# Nearest to with: realistic, environmentalists, chronicling, kodak, dollfuss, dnow, megabyte, publ,
# Nearest to to: reordering, producers, calcium, slime, amalthea, aggressiveness, serial, armament,
# Nearest to while: longitudes, calculate, biollante, abbot, hd, purges, statements, ponies,
# Nearest to as: prosperity, hammer, bertha, stanza, biarritz, label, degrading, capillary,
# Nearest to state: bostonians, registration, lincos, vostok, deal, evolutionists, tracts, antwerp,
# Nearest to such: haute, lepers, bengals, vitality, highbury, intellectualism, alcor, arg,
# Nearest to up: administrator, hera, websites, alteration, er, parrots, causes, holes,
# Nearest to th: strict, numerical, guelfs, charlize, jerzy, gbit, parliament, danny,
# Nearest to than: oates, west, synthesizing, capetian, comore, institutional, countercultural, eager,
# Nearest to from: grille, harrier, aldous, krause, vote, sz, hyperfocal, plutinos,
# Nearest to his: boccaccio, accede, bizarre, morr, udf, sabina, supersonic, gediminas,
# Nearest to four: corte, fickle, pace, misrepresented, expunged, paged, concentrates, clumsy,
# Average loss at step 2000: 4.357938
# Average loss at step 4000: 3.867330
# Average loss at step 6000: 3.783844
# Average loss at step 8000: 3.688327
# Average loss at step 10000: 3.616852
# Nearest to they: he, it, not, we, listeners, bra, who, pxe,
# Nearest to all: several, spectator, some, communicating, novo, catullus, contributions, respect,
# Nearest to five: six, eight, four, seven, nine, three, two, zero,
# Nearest to three: six, four, seven, five, eight, two, zero, nine,
# Nearest to with: in, realistic, for, temperatures, mallow, aargau, pigpen, kyrgyz,
# Nearest to to: engel, will, alegre, would, therapist, armament, hypotension, monolith,
# Nearest to while: abbot, drafted, conquering, dwan, aquarists, ponies, airshows, nationalist,
# Nearest to as: metabolized, stanza, merz, maoists, payload, hawley, governed, btr,
# Nearest to state: registration, lausanne, bostonians, lincos, rabba, belgica, aed, front,
# Nearest to such: haute, highbury, emery, desirable, confidant, tzara, alemanni, bengals,
# Nearest to up: administrator, websites, hera, cristo, herndon, causes, alteration, monks,
# Nearest to th: four, strict, bc, kilkenny, interned, parliament, acetylcholine, six,
# Nearest to than: or, oates, impaired, neutrino, bugatti, observers, foederati, hindu,
# Nearest to from: in, by, through, angie, during, beaufort, estimators, into,
# Nearest to his: their, its, the, s, sized, her, luzon, bowing,
# Nearest to four: six, three, five, eight, seven, two, zero, nine,
# Average loss at step 12000: 3.604492
# Average loss at step 14000: 3.569076
# Average loss at step 16000: 3.407094
# Average loss at step 18000: 3.456159
# Average loss at step 20000: 3.540587
# Nearest to they: he, we, there, it, who, she, not, bandleader,
# Nearest to all: several, many, these, some, quail, those, spectator, the,
# Nearest to five: four, three, six, seven, eight, zero, two, nine,
# Nearest to three: five, four, two, six, eight, seven, zero, nine,
# Nearest to with: in, mallow, for, into, aargau, temperatures, by, duplex,
# Nearest to to: complexes, engel, will, may, could, not, compatible, armament,
# Nearest to while: conquering, including, vicars, reincarnation, nationalist, dwan, abbot, with,
# Nearest to as: maoists, become, metabolized, otaku, prosperity, cameroons, payload, jeux,
# Nearest to state: registration, aed, lausanne, greenland, rabba, belgica, antwerp, mercantile,
# Nearest to such: known, haute, these, well, desirable, tzara, emery, katakana,
# Nearest to up: cristo, lethbridge, monks, administrator, alteration, hayling, colombo, causes,
# Nearest to th: bc, interned, rd, acetylcholine, transsexualism, strict, studi, antiochian,
# Nearest to than: or, oates, neutrino, merz, bugatti, gaku, layla, joanna,
# Nearest to from: in, through, into, tauris, by, and, during, hogarth,
# Nearest to his: their, her, its, the, bowing, these, this, sized,
# Nearest to four: five, eight, six, three, seven, two, nine, zero,
# Average loss at step 22000: 3.500347
# Average loss at step 24000: 3.490410
# Average loss at step 26000: 3.482136
# Average loss at step 28000: 3.478793
# Average loss at step 30000: 3.502534
# Nearest to they: we, there, he, it, who, you, she, these,
# Nearest to all: some, those, any, several, these, many, spectator, elin,
# Nearest to five: four, eight, six, seven, three, nine, zero, two,
# Nearest to three: four, five, eight, six, seven, two, nine, zero,
# Nearest to with: between, mallow, for, into, by, while, ringing, against,
# Nearest to to: engel, will, can, would, not, therapist, must, could,
# Nearest to while: when, but, reincarnation, conquering, ltcm, with, abakan, is,
# Nearest to as: payload, spiced, metabolize, asphyxia, became, elena, aikido, fundraiser,
# Nearest to state: registration, front, lausanne, aed, rabba, antwerp, mormon, differentiation,
# Nearest to such: well, known, these, deliverance, desirable, haute, yr, guano,
# Nearest to up: cristo, off, them, lethbridge, out, municipality, monks, colombo,
# Nearest to th: bc, rd, bce, interned, transsexualism, millisecond, studi, lemmings,
# Nearest to than: or, neutrino, merz, brewer, bugatti, interbreed, ctrl, much,
# Nearest to from: into, through, between, under, in, tauris, during, by,
# Nearest to his: their, her, its, the, s, kew, bowing, supersonic,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Average loss at step 32000: 3.500088
# Average loss at step 34000: 3.499394
# Average loss at step 36000: 3.452278
# Average loss at step 38000: 3.303838
# Average loss at step 40000: 3.428421
# Nearest to they: we, there, he, it, you, these, she, really,
# Nearest to all: any, each, those, elin, furtherance, several, out, many,
# Nearest to five: seven, six, four, three, zero, eight, nine, two,
# Nearest to three: four, seven, six, five, two, eight, zero, nine,
# Nearest to with: mallow, birley, between, realistic, when, in, bauds, by,
# Nearest to to: can, could, must, will, or, complexes, would, monolith,
# Nearest to while: when, although, after, conquering, reincarnation, where, are, but,
# Nearest to as: legitimate, cameroons, spiced, metabolized, marques, be, by, dharmas,
# Nearest to state: registration, government, front, aed, rabba, mormon, antwerp, heal,
# Nearest to such: well, these, known, deliverance, including, many, guano, regarded,
# Nearest to up: off, them, back, down, out, cristo, him, legion,
# Nearest to th: bc, rd, lemmings, bce, interned, jerzy, kurt, st,
# Nearest to than: or, neutrino, much, unidentified, jstor, contends, merz, rowland,
# Nearest to from: into, through, in, during, by, messe, to, within,
# Nearest to his: her, their, its, the, my, s, our, supersonic,
# Nearest to four: six, three, five, eight, seven, two, nine, zero,
# Average loss at step 42000: 3.437841
# Average loss at step 44000: 3.453472
# Average loss at step 46000: 3.450032
# Average loss at step 48000: 3.352889
# Average loss at step 50000: 3.386590
# Nearest to they: he, we, there, you, she, it, who, really,
# Nearest to all: each, those, these, many, any, elin, both, some,
# Nearest to five: four, six, eight, seven, zero, nine, three, two,
# Nearest to three: six, four, eight, seven, five, two, nine, zero,
# Nearest to with: between, mallow, against, when, by, while, birley, pigpen,
# Nearest to to: would, could, can, engel, may, should, innodb, will,
# Nearest to while: when, although, after, where, however, if, but, including,
# Nearest to as: metabolize, merz, armoured, substituting, became, dharmas, georges, birthdays,
# Nearest to state: registration, front, aed, plant, government, galaxies, utensils, rabba,
# Nearest to such: well, these, many, known, regarded, deliverance, generically, pp,
# Nearest to up: off, them, out, down, back, him, cristo, viceroys,
# Nearest to th: bc, rd, bce, kurt, jerzy, lemmings, twentieth, three,
# Nearest to than: much, or, interbreed, gaku, apologia, merz, neutrino, ctrl,
# Nearest to from: through, into, during, in, under, tauris, after, promo,
# Nearest to his: their, her, its, my, your, the, supersonic, him,
# Nearest to four: six, five, eight, seven, three, nine, two, zero,
# Average loss at step 52000: 3.431716
# Average loss at step 54000: 3.431214
# Average loss at step 56000: 3.435658
# Average loss at step 58000: 3.396965
# Average loss at step 60000: 3.391526
# Nearest to they: we, there, you, he, she, it, who, really,
# Nearest to all: those, these, many, elin, any, each, both, some,
# Nearest to five: four, six, eight, three, seven, nine, zero, two,
# Nearest to three: five, four, eight, six, seven, two, nine, zero,
# Nearest to with: between, mallow, when, by, compare, although, fruitarians, pigpen,
# Nearest to to: engel, would, only, will, hypotension, complexes, xxx, cannot,
# Nearest to while: when, although, after, including, before, if, though, without,
# Nearest to as: cameroons, became, metabolized, pitot, metabolize, jeux, thumbnail, alloy,
# Nearest to state: registration, government, plant, aed, heal, berlitz, front, utensils,
# Nearest to such: these, well, many, known, including, deliverance, regarded, desirable,
# Nearest to up: off, out, down, them, back, him, cristo, daring,
# Nearest to th: bc, rd, bce, twentieth, five, four, anglian, nd,
# Nearest to than: much, or, interbreed, far, zeta, and, gaku, herbivores,
# Nearest to from: through, into, in, tauris, impetuous, during, under, since,
# Nearest to his: her, their, its, my, your, the, sponsorship, potion,
# Nearest to four: five, six, eight, seven, three, nine, two, zero,
# Average loss at step 62000: 3.241043
# Average loss at step 64000: 3.253702
# Average loss at step 66000: 3.402950
# Average loss at step 68000: 3.391200
# Average loss at step 70000: 3.365851
# Nearest to they: we, he, there, you, she, it, who, not,
# Nearest to all: many, those, some, any, each, these, every, several,
# Nearest to five: four, six, three, seven, eight, zero, nine, two,
# Nearest to three: four, five, six, two, seven, eight, nine, zero,
# Nearest to with: between, mallow, when, against, while, in, fruitarians, seyss,
# Nearest to to: engel, would, will, must, complexes, can, may, sleeves,
# Nearest to while: although, when, after, where, including, before, if, however,
# Nearest to as: electrochemical, imaging, pitot, cameroons, like, bridgehead, when, emoticons,
# Nearest to state: government, registration, city, aed, states, cellulose, pelletier, plant,
# Nearest to such: these, well, known, many, regarded, including, some, other,
# Nearest to up: off, them, down, out, back, him, cristo, lawn,
# Nearest to th: bc, bce, rd, st, twentieth, third, anglian, jerzy,
# Nearest to than: much, or, interbreed, gaku, far, zeta, homonyms, no,
# Nearest to from: through, into, between, within, during, in, under, moustache,
# Nearest to his: her, their, its, my, your, our, kew, luzon,
# Nearest to four: six, five, seven, three, eight, zero, nine, two,
# Average loss at step 72000: 3.377191
# Average loss at step 74000: 3.347252
# Average loss at step 76000: 3.317433
# Average loss at step 78000: 3.351889
# Average loss at step 80000: 3.379371
# Nearest to they: we, he, there, you, she, it, who, these,
# Nearest to all: both, any, each, every, several, these, elin, those,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to three: five, six, seven, four, two, eight, nine, zero,
# Nearest to with: between, mallow, when, through, in, choi, seaway, litovsk,
# Nearest to to: engel, will, slime, should, would, merges, armament, bodied,
# Nearest to while: although, after, when, including, or, allows, before, however,
# Nearest to as: asphyxia, elena, merz, cameroons, blotting, substituting, became, storehouse,
# Nearest to state: government, registration, city, states, aed, greenland, cellulose, reflective,
# Nearest to such: well, these, regarded, known, follows, including, many, deliverance,
# Nearest to up: off, out, down, them, back, him, away, cristo,
# Nearest to th: bc, rd, st, bce, twentieth, third, jerzy, lemmings,
# Nearest to than: much, or, interbreed, and, while, homonyms, carmelite, jstor,
# Nearest to from: through, into, within, during, in, by, under, via,
# Nearest to his: her, their, its, my, your, our, the, kew,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Average loss at step 82000: 3.409089
# Average loss at step 84000: 3.407642
# Average loss at step 86000: 3.388937
# Average loss at step 88000: 3.351247
# Average loss at step 90000: 3.365610
# Nearest to they: we, he, she, you, there, it, but, gush,
# Nearest to all: several, both, many, some, these, those, each, every,
# Nearest to five: seven, four, six, eight, three, nine, zero, two,
# Nearest to three: five, four, two, seven, eight, six, nine, zero,
# Nearest to with: between, when, choi, against, pkn, in, birley, mallow,
# Nearest to to: engel, would, slime, will, should, merges, sleeves, for,
# Nearest to while: although, when, after, before, and, though, including, were,
# Nearest to as: pitot, dharmas, cameroons, metabolize, saterland, electrochemical, austrian, metabolized,
# Nearest to state: government, registration, city, states, greenland, aed, cellulose, lausanne,
# Nearest to such: known, well, these, regarded, follows, bouts, including, gradient,
# Nearest to up: off, out, back, down, them, away, him, together,
# Nearest to th: bc, bce, rd, twentieth, st, one, seven, lemmings,
# Nearest to than: much, interbreed, knighted, bains, even, or, no, homonyms,
# Nearest to from: through, into, during, via, before, within, under, in,
# Nearest to his: her, their, its, your, my, our, the, s,
# Nearest to four: five, six, eight, seven, three, two, nine, zero,
# Average loss at step 92000: 3.399818
# Average loss at step 94000: 3.251827
# Average loss at step 96000: 3.360083
# Average loss at step 98000: 3.245067
# Average loss at step 100000: 3.357730
# Nearest to they: we, he, there, you, she, it, i, not,
# Nearest to all: these, those, several, every, many, both, any, some,
# Nearest to five: four, seven, eight, six, zero, three, nine, two,
# Nearest to three: five, four, six, eight, seven, two, zero, nine,
# Nearest to with: between, including, birley, through, when, humphreys, in, into,
# Nearest to to: will, could, should, would, must, cannot, engel, can,
# Nearest to while: although, when, after, but, though, before, where, and,
# Nearest to as: pitot, substituting, like, asphyxia, emoticons, torrey, cameroons, lateran,
# Nearest to state: government, city, registration, greenland, aed, states, lausanne, reflective,
# Nearest to such: known, well, including, follows, regarded, these, many, stipulate,
# Nearest to up: off, out, back, them, down, him, away, together,
# Nearest to th: bc, rd, bce, twentieth, third, st, anglian, jerzy,
# Nearest to than: or, much, interbreed, judy, zeta, and, tempore, existentialist,
# Nearest to from: into, through, in, within, during, tauris, under, sarmatians,
# Nearest to his: her, their, your, my, its, our, the, s,
# Nearest to four: six, five, seven, eight, three, nine, zero, two,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        # WOW SUCH CBOW
        batch_labels, batch_data = generate_batch(batch_size, num_skips, skip_window)
        batch_data = batch_data.reshape((batch_size,))
        batch_labels = batch_labels.reshape((batch_size, 1))
        
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From c:\users\nwaller\appdata\local\continuum\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\tf_should_use.py:175: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 8.533407
# Nearest to they: stanislavski, keynes, suri, vocational, fournier, ussachevsky, lysis, christianization,
# Nearest to all: weak, wu, fated, throughout, detachable, directness, bert, giancana,
# Nearest to five: admirer, romanian, cavalier, withheld, embedded, beatified, homomorphism, causative,
# Nearest to three: keep, rcr, eulemur, ligurian, inmarsat, actions, sato, gaddis,
# Nearest to with: salvaged, dvo, convincingly, vaccinium, vault, shootings, fevers, rodgers,
# Nearest to to: reserves, trunks, clams, bounty, postulates, sexagesimal, egalitarian, grigori,
# Nearest to while: mm, penal, recherche, tyr, melvins, fayette, bending, syndrome,
# Nearest to as: secondarily, monuc, capt, calamine, mutinied, epistemological, painful, yoga,
# Nearest to state: obedience, audiovisual, sligo, obsoletes, pippin, figures, incipient, lennox,
# Nearest to such: contest, mes, detachments, enchanted, mustaine, screenshots, lactantius, thermometers,
# Nearest to up: predatory, truncation, therein, amplification, scylla, alphanumeric, pressure, afro,
# Nearest to th: tangent, segal, taxpayer, democritus, versed, eeg, messiaen, resolution,
# Nearest to than: fourths, ktav, bae, mic, swelling, heth, ell, inscription,
# Nearest to from: tithes, ibadi, passed, functional, bohemians, rabba, taboo, monarch,
# Nearest to his: billionaire, nicol, darrell, inanimate, musicianship, ricans, windowing, humankind,
# Nearest to four: demonstration, engravers, organizing, lieder, brazen, samhain, resolutely, philippe,
# Average loss at step 2000: 4.380894
# Average loss at step 4000: 3.871523
# Average loss at step 6000: 3.797645
# Average loss at step 8000: 3.759967
# Average loss at step 10000: 3.623596
# Nearest to they: he, we, it, that, jt, assignment, not, handily,
# Nearest to all: some, reused, their, wu, pump, vest, presides, many,
# Nearest to five: six, four, three, eight, zero, nine, seven, two,
# Nearest to three: four, five, six, two, seven, eight, nine, zero,
# Nearest to with: in, by, and, on, between, waived, earthy, salvaged,
# Nearest to to: into, unfiltered, with, in, collectivized, and, boac, surreal,
# Nearest to while: penal, recherche, tyr, every, mm, desktops, syndrome, buckle,
# Nearest to as: parallax, snowfall, into, calamine, outfield, heathland, monuc, by,
# Nearest to state: basics, love, slab, kristofferson, schuler, fatalities, fft, work,
# Nearest to such: well, mes, siouxsie, contest, alexanderplatz, known, expressionism, portrayal,
# Nearest to up: amplification, therein, predatory, kushan, aphrodite, truncation, scylla, ordinations,
# Nearest to th: tangent, taxpayer, democritus, bayan, segal, resolution, products, enshrined,
# Nearest to than: mic, swelling, trainers, statistics, harbored, leaned, bae, inflation,
# Nearest to from: in, and, adjectival, on, by, into, monarch, stuttgart,
# Nearest to his: their, its, the, inanimate, my, regional, jackie, billionaire,
# Nearest to four: three, five, six, eight, seven, nine, zero, two,
# Average loss at step 12000: 3.580230
# Average loss at step 14000: 3.615083
# Average loss at step 16000: 3.587955
# Average loss at step 18000: 3.572344
# Average loss at step 20000: 3.551105
# Nearest to they: he, there, we, it, you, these, who, assignment,
# Nearest to all: many, some, these, those, both, their, pump, several,
# Nearest to five: six, eight, seven, four, nine, zero, three, two,
# Nearest to three: four, five, seven, two, eight, six, nine, zero,
# Nearest to with: between, persephone, in, by, reputations, waived, wells, on,
# Nearest to to: would, can, will, in, for, unfiltered, sousa, surreal,
# Nearest to while: desktops, kim, squire, buckle, penal, scarlatti, melvins, wayne,
# Nearest to as: by, from, degraded, consider, is, eurofighter, lba, into,
# Nearest to state: basics, noi, hemispheres, kristofferson, love, liguria, industrial, anscombe,
# Nearest to such: well, known, many, regarded, regional, confines, alexanderplatz, some,
# Nearest to up: out, aphrodite, them, amplification, saxons, kushan, seagram, su,
# Nearest to th: tangent, taxpayer, bayan, democritus, irresponsibility, frud, segal, zero,
# Nearest to than: inflation, or, much, trainers, mic, harbored, swelling, ell,
# Nearest to from: in, into, by, before, narrows, through, after, during,
# Nearest to his: their, her, its, the, my, s, regional, darrell,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Average loss at step 22000: 3.529412
# Average loss at step 24000: 3.439643
# Average loss at step 26000: 3.416453
# Average loss at step 28000: 3.474013
# Average loss at step 30000: 3.406716
# Nearest to they: he, we, there, you, it, not, she, these,
# Nearest to all: many, these, those, both, some, parts, shipments, facsimile,
# Nearest to five: seven, eight, six, four, three, nine, zero, two,
# Nearest to three: four, five, seven, six, two, eight, nine, zero,
# Nearest to with: between, by, in, arras, when, airstrip, salvaged, congresses,
# Nearest to to: would, will, sousa, could, can, cordell, unfiltered, highlanders,
# Nearest to while: desktops, melvins, however, automorphisms, scarlatti, tyr, vitality, syndrome,
# Nearest to as: lba, redundantly, monuc, by, formally, into, unified, uncharacteristic,
# Nearest to state: basics, fft, sayles, anscombe, wittenberg, noi, kristofferson, centauri,
# Nearest to such: well, known, these, many, denomination, confines, psychologist, regarded,
# Nearest to up: out, them, aphrodite, seagram, cabo, down, amplification, kushan,
# Nearest to th: tangent, taxpayer, xc, segal, irresponsibility, bayan, caterpillars, frud,
# Nearest to than: much, or, plausibility, harbored, giga, mic, inflation, complex,
# Nearest to from: into, through, in, between, after, during, towards, wi,
# Nearest to his: their, her, its, the, my, bjp, warns, claus,
# Nearest to four: seven, five, six, three, eight, nine, two, zero,
# Average loss at step 32000: 3.420157
# Average loss at step 34000: 3.440830
# Average loss at step 36000: 3.358444
# Average loss at step 38000: 3.497185
# Average loss at step 40000: 3.441716
# Nearest to they: we, he, there, it, you, who, she, these,
# Nearest to all: both, these, many, some, various, those, several, buick,
# Nearest to five: four, zero, six, eight, seven, two, three, nine,
# Nearest to three: five, six, two, eight, four, seven, zero, nine,
# Nearest to with: between, when, by, vend, persephone, reputations, inconvenient, congresses,
# Nearest to to: will, would, egalitarian, sousa, cordell, must, chengdu, uniqueness,
# Nearest to while: however, though, although, but, when, desktops, during, mucous,
# Nearest to as: euros, redundantly, torturing, uncharacteristic, when, formally, debugger, capt,
# Nearest to state: panel, basics, bundle, wittenberg, anscombe, tiger, sayles, schuler,
# Nearest to such: well, known, these, many, described, regarded, some, confines,
# Nearest to up: out, them, down, back, seagram, aphrodite, together, cabo,
# Nearest to th: tangent, taxpayer, xc, frud, caterpillars, bien, bayan, irresponsibility,
# Nearest to than: much, plausibility, or, cremona, mic, inflation, harbored, finer,
# Nearest to from: into, in, narrows, through, towards, during, after, usaf,
# Nearest to his: her, their, its, my, the, s, darrell, warns,
# Nearest to four: five, seven, six, eight, three, nine, zero, two,
# Average loss at step 42000: 3.426159
# Average loss at step 44000: 3.274467
# Average loss at step 46000: 3.408986
# Average loss at step 48000: 3.436368
# Average loss at step 50000: 3.437709
# Nearest to they: we, he, there, you, she, it, assignment, these,
# Nearest to all: both, some, many, these, various, several, those, avercamp,
# Nearest to five: four, six, seven, eight, three, zero, nine, two,
# Nearest to three: four, six, five, two, seven, eight, zero, nine,
# Nearest to with: between, by, in, persephone, airstrip, chapterhouse, and, ku,
# Nearest to to: will, sousa, could, must, would, can, may, unfiltered,
# Nearest to while: although, when, however, though, but, after, desktops, without,
# Nearest to as: eurofighter, uncharacteristic, ole, euros, parmenides, revolver, heathland, redundantly,
# Nearest to state: government, basics, panel, wittenberg, cords, tiger, jericho, anscombe,
# Nearest to such: well, known, described, these, confines, denomination, negotiation, including,
# Nearest to up: out, down, them, back, through, seagram, together, cabo,
# Nearest to th: one, seven, five, st, taxpayer, emigr, frud, xc,
# Nearest to than: much, or, plausibility, harbored, finer, oblong, cremona, subpixel,
# Nearest to from: into, through, in, between, across, under, mink, usaf,
# Nearest to his: her, their, its, my, the, our, monopoly, s,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Average loss at step 52000: 3.454211
# Average loss at step 54000: 3.430865
# Average loss at step 56000: 3.403550
# Average loss at step 58000: 3.279700
# Average loss at step 60000: 3.381487
# Nearest to they: we, he, there, you, she, it, these, assignment,
# Nearest to all: both, many, some, various, these, several, those, peerages,
# Nearest to five: six, four, eight, three, seven, nine, zero, two,
# Nearest to three: five, four, eight, two, six, seven, nine, zero,
# Nearest to with: between, vend, towards, persephone, in, dez, by, harvest,
# Nearest to to: would, could, will, against, unfiltered, uml, lc, should,
# Nearest to while: although, but, though, however, when, before, after, reduces,
# Nearest to as: became, uncharacteristic, while, euros, parkes, eurofighter, redundantly, formally,
# Nearest to state: government, panel, tiger, basics, cords, sarcophagus, chalice, jericho,
# Nearest to such: well, known, many, these, subspace, described, regional, negotiation,
# Nearest to up: out, down, back, them, together, him, through, off,
# Nearest to th: four, five, eight, st, six, two, one, nine,
# Nearest to than: or, plausibility, much, hume, finer, mutagenesis, cabins, subpixel,
# Nearest to from: through, into, across, under, haworth, by, between, during,
# Nearest to his: her, their, my, its, the, our, darrell, mcqueen,
# Nearest to four: five, six, three, seven, eight, nine, two, zero,
# Average loss at step 62000: 3.439398
# Average loss at step 64000: 3.365181
# Average loss at step 66000: 3.342909
# Average loss at step 68000: 3.388048
# Average loss at step 70000: 3.373790
# Nearest to they: we, he, you, there, she, who, these, it,
# Nearest to all: both, many, some, various, several, those, these, hundreds,
# Nearest to five: four, eight, six, seven, nine, three, zero, two,
# Nearest to three: four, five, eight, two, seven, six, nine, zero,
# Nearest to with: between, by, vend, when, although, through, persephone, against,
# Nearest to to: would, will, sousa, can, could, cannot, cordell, doubleheader,
# Nearest to while: although, though, but, when, and, however, if, after,
# Nearest to as: redundantly, parkes, became, climbers, euros, while, nichiren, lba,
# Nearest to state: government, panel, sarcophagus, basics, cords, tiger, jericho, noi,
# Nearest to such: well, these, known, many, subspace, some, regional, negotiation,
# Nearest to up: out, down, back, them, off, through, him, together,
# Nearest to th: eight, five, seven, six, two, nine, four, st,
# Nearest to than: or, much, plausibility, finer, converters, fine, cabins, energetics,
# Nearest to from: through, into, across, during, between, in, haworth, sorcerer,
# Nearest to his: her, their, my, its, the, our, s, darrell,
# Nearest to four: five, six, eight, seven, three, nine, zero, two,
# Average loss at step 72000: 3.405441
# Average loss at step 74000: 3.392931
# Average loss at step 76000: 3.348336
# Average loss at step 78000: 3.232634
# Average loss at step 80000: 3.372529
# Nearest to they: we, there, you, he, she, it, these, who,
# Nearest to all: both, those, every, various, avercamp, many, peerages, some,
# Nearest to five: four, seven, eight, six, three, nine, zero, two,
# Nearest to three: four, five, six, two, seven, eight, zero, nine,
# Nearest to with: between, when, persephone, without, in, airstrip, dez, meteorological,
# Nearest to to: will, can, would, sousa, could, chengdu, might, may,
# Nearest to while: although, though, however, when, and, before, including, for,
# Nearest to as: redundantly, unified, eurofighter, incheon, when, by, plectrum, parkes,
# Nearest to state: government, sarcophagus, panel, altenberg, tiger, basics, pseudonym, national,
# Nearest to such: well, these, known, negotiation, described, many, having, distraught,
# Nearest to up: out, back, down, them, off, together, him, ova,
# Nearest to th: five, eight, six, nine, st, seven, zoot, showa,
# Nearest to than: or, much, energetics, finer, plausibility, cabins, rsc, even,
# Nearest to from: through, across, into, between, usaf, mink, under, haworth,
# Nearest to his: her, their, my, its, the, your, our, s,
# Nearest to four: five, six, seven, three, eight, nine, zero, two,
# Average loss at step 82000: 3.295248
# Average loss at step 84000: 3.346648
# Average loss at step 86000: 3.344787
# Average loss at step 88000: 3.322630
# Average loss at step 90000: 3.240333
# Nearest to they: we, he, there, you, she, it, i, assignment,
# Nearest to all: both, various, several, many, every, these, some, those,
# Nearest to five: seven, four, eight, nine, six, three, zero, two,
# Nearest to three: four, five, seven, two, six, eight, nine, zero,
# Nearest to with: between, through, by, airstrip, in, towards, arras, salvaged,
# Nearest to to: would, will, sousa, abdomen, countable, egalitarian, unfiltered, biologically,
# Nearest to while: although, however, though, but, when, before, felt, and,
# Nearest to as: ole, empress, lends, kosovar, favours, after, before, geddy,
# Nearest to state: government, states, promoter, altenberg, panel, tiger, moors, kilometre,
# Nearest to such: well, these, known, seen, served, having, regional, regarded,
# Nearest to up: out, back, them, down, off, together, him, ova,
# Nearest to th: eight, zero, five, seven, bc, nico, eighteenth, four,
# Nearest to than: or, plausibility, much, finer, cabins, no, energetics, sopwith,
# Nearest to from: through, across, into, between, haworth, by, decrypts, before,
# Nearest to his: her, their, its, my, our, the, s, your,
# Nearest to four: five, seven, six, eight, three, nine, zero, two,
# Average loss at step 92000: 2.734427
# Average loss at step 94000: 3.100596
# Average loss at step 96000: 3.063696
# Average loss at step 98000: 3.221188
# Average loss at step 100000: 3.281290
# Nearest to they: we, he, you, there, she, i, it, however,
# Nearest to all: both, these, every, various, several, those, avercamp, many,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to with: between, by, through, airstrip, lerner, dez, reputations, arras,
# Nearest to to: will, can, would, countable, must, abdomen, doubleheader, egalitarian,
# Nearest to while: although, though, however, when, but, before, began, after,
# Nearest to as: redundantly, formally, parkes, ole, cryptographer, tum, pseudo, oft,
# Nearest to state: government, states, altenberg, pseudonym, panel, national, city, choice,
# Nearest to such: well, these, known, many, regarded, those, negotiation, including,
# Nearest to up: out, back, down, off, them, together, him, ova,
# Nearest to th: butcher, seven, rd, nd, fourth, bc, st, eighteenth,
# Nearest to than: or, much, plausibility, cabins, combining, chance, finer, slightly,
# Nearest to from: through, under, across, akad, in, haworth, between, narrows,
# Nearest to his: her, their, its, my, your, the, bjp, our,
# Nearest to four: five, seven, six, three, eight, nine, zero, two,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
